# %%
import numpy as np
import pandas as pd

from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from sklearn.cross_validation import train_test_split

import seaborn as sn

import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

import math
# Out:
# C:\Users\Ospan\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# C:\Users\Ospan\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
df_Android_U=pd.read_csv("C:/Users/Ospan/Desktop/Kolesa/AutoCredit/Data N8/Android_Users.csv")
df_Android_U = df_Android_U[['Дата','Просмотры объявлений (Легковые с пробегом)','Просмотры телефонов (Легковые с пробегом)', '"В кредит" (Объявление) Клики','"Получить одобрение" (Калькулятор) Подтверждения','"Продолжить" (Большая анкета) Подтверждения','Заявки все (Одобрено, Альтернатива, Отказы)']]
line = pd.DataFrame({"platform": "ANDROID", "event_name": 'message_send'}, index=[2.5])
df_Android_U = df_Android_U.append(line, ignore_index=False)
df_Android_U = df_Android_U.sort_index().reset_index(drop=True) 
df_Android_U = df_Android_U.reindex(['Дата','Просмотры объявлений (Легковые с пробегом)','Просмотры телефонов (Легковые с пробегом)', '"В кредит" (Объявление) Клики','"Получить одобрение" (Калькулятор) Подтверждения','"Продолжить" (Большая анкета) Подтверждения','Заявки все (Одобрено, Альтернатива, Отказы)'], axis=1)
df_Android_U.loc[3, 'Дата'] = '2020-01-21 00:00:00'
df_Android_U['Дата'] = pd.to_datetime(df_Android_U['Дата'])
df_Android_U = df_Android_U.interpolate()
df_Android_U['EorU']='Пользователи'
df_Android_U['platform'] = 'android'

df_Android_E=pd.read_csv("C:/Users/Ospan/Desktop/Kolesa/AutoCredit/Data N8/Android_Events.csv")
df_Android_E=df_Android_E.rename(columns={"date_filter":"Дата"})
df_Android_E = df_Android_E[['Дата','Просмотры объявлений (Легковые с пробегом)','Просмотры телефонов (Легковые с пробегом)', '"В кредит" (Объявление) Клики','"Получить одобрение" (Калькулятор) Подтверждения','"Продолжить" (Большая анкета) Подтверждения','Заявки все (Одобрено, Альтернатива, Отказы)']]
line = pd.DataFrame({"platform": "ANDROID", "event_name": 'message_send'}, index=[2.5])
df_Android_E = df_Android_E.append(line, ignore_index=False)
df_Android_E = df_Android_E.sort_index().reset_index(drop=True) 
df_Android_E = df_Android_E.reindex(['Дата','Просмотры объявлений (Легковые с пробегом)','Просмотры телефонов (Легковые с пробегом)', '"В кредит" (Объявление) Клики','"Получить одобрение" (Калькулятор) Подтверждения','"Продолжить" (Большая анкета) Подтверждения','Заявки все (Одобрено, Альтернатива, Отказы)'], axis=1)
df_Android_E.loc[3, 'Дата'] = '2020-01-21 00:00:00'
df_Android_E['Дата'] = pd.to_datetime(df_Android_E['Дата'])
df_Android_E = df_Android_E.interpolate()
df_Android_E['EorU']='События'
df_Android_E['platform'] = 'android'

df_IOS_U=pd.read_csv("C:/Users/Ospan/Desktop/Kolesa/AutoCredit/Data N8/IOS_Users.csv")
df_IOS_U = df_IOS_U[['Дата','Просмотры объявлений (Легковые с пробегом)','Просмотры телефонов (Легковые с пробегом)', '"В кредит" (Объявление) Клики','"Получить одобрение" (Калькулятор) Подтверждения','"Продолжить" (Большая анкета) Подтверждения','Заявки все (Одобрено, Альтернатива, Отказы)']]
line = pd.DataFrame({"platform": "ANDROID", "event_name": 'message_send'}, index=[2.5])
df_IOS_U = df_IOS_U.append(line, ignore_index=False)
df_IOS_U = df_IOS_U.sort_index().reset_index(drop=True) 
df_IOS_U = df_IOS_U.reindex(['Дата','Просмотры объявлений (Легковые с пробегом)','Просмотры телефонов (Легковые с пробегом)', '"В кредит" (Объявление) Клики','"Получить одобрение" (Калькулятор) Подтверждения','"Продолжить" (Большая анкета) Подтверждения','Заявки все (Одобрено, Альтернатива, Отказы)'], axis=1)
df_IOS_U.loc[3, 'Дата'] = '2020-01-21 00:00:00'
df_IOS_U['Дата'] = pd.to_datetime(df_IOS_U['Дата'])
df_IOS_U = df_IOS_U.interpolate()
df_IOS_U['EorU']='Пользователи'
df_IOS_U['platform'] = 'ios'


df_IOS_E=pd.read_csv("C:/Users/Ospan/Desktop/Kolesa/AutoCredit/Data N8/IOS_Events.csv")
df_IOS_E=df_IOS_E.rename(columns={"date_filter":"Дата"})
df_IOS_E = df_IOS_E[['Дата','Просмотры объявлений (Легковые с пробегом)','Просмотры телефонов (Легковые с пробегом)', '"В кредит" (Объявление) Клики','"Получить одобрение" (Калькулятор) Подтверждения','"Продолжить" (Большая анкета) Подтверждения','Заявки все (Одобрено, Альтернатива, Отказы)']]
line = pd.DataFrame({"platform": "ANDROID", "event_name": 'message_send'}, index=[2.5])
df_IOS_E = df_IOS_E.append(line, ignore_index=False)
df_IOS_E = df_IOS_E.sort_index().reset_index(drop=True) 
df_IOS_E = df_IOS_E.reindex(['Дата','Просмотры объявлений (Легковые с пробегом)','Просмотры телефонов (Легковые с пробегом)', '"В кредит" (Объявление) Клики','"Получить одобрение" (Калькулятор) Подтверждения','"Продолжить" (Большая анкета) Подтверждения','Заявки все (Одобрено, Альтернатива, Отказы)'], axis=1)
df_IOS_E.loc[3, 'Дата'] = '2020-01-21 00:00:00'
df_IOS_E['Дата'] = pd.to_datetime(df_IOS_E['Дата'])
df_IOS_E = df_IOS_E.interpolate()
df_IOS_E['EorU']='События'
df_IOS_E['platform'] = 'ios'

df_Desktop_U=pd.read_csv("C:/Users/Ospan/Desktop/Kolesa/AutoCredit/Data N8/Desktop_Users.csv")
df_Desktop_U['Дата'] = pd.to_datetime(df_Desktop_U['Дата'])
df_Desktop_U = df_Desktop_U[['Дата',
                             'Просмотры объявлений (Легковые с пробегом)',
                            'Просмотры телефонов (Легковые с пробегом)',
                            '"В кредит" (Объявление) Клики',
                            '"Получить одобрение" (Калькулятор) Подтверждения',
                            '"Продолжить" (Большая анкета) Подтверждения',
                            'Заявки все (Одобрено, Альтернатива, Отказы)']]
df_Desktop_U['EorU']='Пользователи'
df_Desktop_U['platform'] = 'desktop'

df_Desktop_E=pd.read_csv("C:/Users/Ospan/Desktop/Kolesa/AutoCredit/Data N8/Desktop_Events.csv")
df_Desktop_E=df_Desktop_E.rename(columns={"date_filter":"Дата"})
df_Desktop_E['Дата'] = pd.to_datetime(df_Desktop_E['Дата'])
df_Desktop_E = df_Desktop_E[['Дата',
                             'Просмотры объявлений (Легковые с пробегом)',
                            'Просмотры телефонов (Легковые с пробегом)',
                            '"В кредит" (Объявление) Клики',
                            '"Получить одобрение" (Калькулятор) Подтверждения',
                            '"Продолжить" (Большая анкета) Подтверждения',
                            'Заявки все (Одобрено, Альтернатива, Отказы)']]
df_Desktop_E['EorU']='События'
df_Desktop_E['platform'] = 'desktop'

df_Mobile_U=pd.read_csv("C:/Users/Ospan/Desktop/Kolesa/AutoCredit/Data N8/Mobile_Users.csv")
df_Mobile_U['Дата'] = pd.to_datetime(df_Mobile_U['Дата'])
df_Mobile_U = df_Mobile_U[['Дата',
                             'Просмотры объявлений (Легковые с пробегом)',
                            'Просмотры телефонов (Легковые с пробегом)',
                            '"В кредит" (Объявление) Клики',
                            '"Получить одобрение" (Калькулятор) Подтверждения',
                            '"Продолжить" (Большая анкета) Подтверждения',
                            'Заявки все (Одобрено, Альтернатива, Отказы)']]
df_Mobile_U['EorU']='Пользователи'
df_Mobile_U['platform'] = 'mobile'

df_Mobile_E=pd.read_csv("C:/Users/Ospan/Desktop/Kolesa/AutoCredit/Data N8/Mobile_Events.csv")
df_Mobile_E=df_Mobile_E.rename(columns={"date_filter":"Дата"})
df_Mobile_E['Дата'] = pd.to_datetime(df_Mobile_E['Дата'])
df_Mobile_E = df_Mobile_E[['Дата',
                             'Просмотры объявлений (Легковые с пробегом)',
                            'Просмотры телефонов (Легковые с пробегом)',
                            '"В кредит" (Объявление) Клики',
                            '"Получить одобрение" (Калькулятор) Подтверждения',
                            '"Продолжить" (Большая анкета) Подтверждения',
                            'Заявки все (Одобрено, Альтернатива, Отказы)']]
df_Mobile_E['EorU']='События'
df_Mobile_E['platform'] = 'mobile'

df_Sent_First_Message=pd.read_csv("C:/Users/Ospan/Desktop/Kolesa/AutoCredit/Data N8/Sent_First_Message_Desktop.csv", sep=',')
df_Sent_First_Message_App=pd.read_csv("C:/Users/Ospan/Desktop/Kolesa/AutoCredit/Data N8/Sent_First_Message_Apps.csv", sep=',')

df_Sent_First_Message_App['platform'] = df_Sent_First_Message_App['platform'].str.lower()
df_Sent_First_Message_App['date'] = df_Sent_First_Message_App['date'].apply(lambda x: pd.to_datetime(str(x), format='%Y%m%d'))
df_Sent_First_Message_App=df_Sent_First_Message_App.sort_values(by='date')
df_Sent_First_Message_App.reset_index(drop=True, inplace=True)

df_Sent_First_Message['date'] = pd.to_datetime(df_Sent_First_Message['date'])
df_Sent_First_Message=df_Sent_First_Message.sort_values(by='date')
df_Sent_First_Message.reset_index(drop=True, inplace=True)

df_baza_listers=pd.read_csv("C:/Users/Ospan/Desktop/Kolesa/AutoCredit/Data N8/listers_baza_new.csv")
df_baza_listers = df_baza_listers.sort_values(by='execution_date') 
df_baza_listers.reset_index(drop=True, inplace=True)
df_baza_listers['execution_date'] = pd.to_datetime(df_baza_listers['execution_date'])
df_baza_listers = df_baza_listers.rename(columns={"execution_date": "date"})

df_baza = df_baza_listers.drop(columns = ['listers'])
df_listers = df_baza_listers.drop(columns = ['objem_bazy'])
df_baza.head()
df_Sent_First_Message_App.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-46b87dd4d451> in <module>()
# ----> 1 df_Android_U=pd.read_csv("C:/Users/Ospan/Desktop/Kolesa/AutoCredit/Data N8/Android_Users.csv")
#       2 df_Android_U = df_Android_U[['Дата','Просмотры объявлений (Легковые с пробегом)','Просмотры телефонов (Легковые с пробегом)', '"В кредит" (Объявление) Клики','"Получить одобрение" (Калькулятор) Подтверждения','"Продолжить" (Большая анкета) Подтверждения','Заявки все (Одобрено, Альтернатива, Отказы)']]
#       3 line = pd.DataFrame({"platform": "ANDROID", "event_name": 'message_send'}, index=[2.5])
#       4 df_Android_U = df_Android_U.append(line, ignore_index=False)
#       5 df_Android_U = df_Android_U.sort_index().reset_index(drop=True)
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'C:/Users/Ospan/Desktop/Kolesa/AutoCredit/Data N8/Android_Users.csv' does not exist

# %%
df_baza_listers=pd.read_csv("C:/Users/Ospan/Desktop/Kolesa/AutoCredit/CorrelationCredit/Data N8/listers_baza_new.csv")
df_baza_listers = df_baza_listers.sort_values(by='date') 
df_baza_listers.reset_index(drop=True, inplace=True)
df_baza_listers['date'] = pd.to_datetime(df_baza_listers['date'])
df_baza_listers.dtypes
# Out:
# date          datetime64[ns]
# platform              object
# objem_bazy             int64
# listers                int64
# dtype: object

# %% [markdown]
# # First table

# %%
Credit_Events = df_Android_U.append([df_Android_E,df_IOS_U,df_IOS_E,df_Desktop_U,df_Desktop_E,df_Mobile_U,df_Mobile_E],ignore_index = True)

# %%
Credit_Events
# Out:
#           Дата  Просмотры объявлений (Легковые с пробегом)  \
# 0   2020-01-18                                    367826.0
# 1   2020-01-19                                    384200.0
# 2   2020-01-20                                    393510.0
# 3   2020-01-21                                    390412.0
# 4   2020-01-22                                    387314.0
# 5   2020-01-23                                    374140.0
# 6   2020-01-24                                    371825.0
# 7   2020-01-25                                    378744.0
# 8   2020-01-26                                    392216.0
# 9   2020-01-27                                    382863.0
# 10  2020-01-28                                    374269.0
# 11  2020-01-29                                    368805.0
# 12  2020-01-30                                    370615.0
# 13  2020-01-31                                    366730.0
# 14  2020-02-01                                    371432.0
# 15  2020-02-02                                    393792.0
# 16  2020-02-03                                    397048.0
# 17  2020-02-04                                    390336.0
# 18  2020-02-05                                    382239.0
# 19  2020-02-06                                    381981.0
# 20  2020-02-07                                    363748.0
# 21  2020-02-08                                    342810.0
# 22  2020-02-09                                    374454.0
# 23  2020-02-10                                    375769.0
# 24  2020-02-11                                    371066.0
# 25  2020-02-12                                    370908.0
# 26  2020-02-13                                    368804.0
# 27  2020-02-14                                    350864.0
# 28  2020-02-15                                    363119.0
# 29  2020-02-16                                    387231.0
# ..         ...                                         ...
# 226 2020-01-20                                    557876.0
# 227 2020-01-21                                    527340.0
# 228 2020-01-22                                    531876.0
# 229 2020-01-23                                    507075.0
# 230 2020-01-24                                    481443.0
# 231 2020-01-25                                    512715.0
# 232 2020-01-26                                    566666.0
# 233 2020-01-27                                    508061.0
# 234 2020-01-28                                    491891.0
# 235 2020-01-29                                    482343.0
# 236 2020-01-30                                    492497.0
# 237 2020-01-31                                    471970.0
# 238 2020-02-01                                    496231.0
# 239 2020-02-02                                    565972.0
# 240 2020-02-03                                    534803.0
# 241 2020-02-04                                    526675.0
# 242 2020-02-05                                    510299.0
# 243 2020-02-06                                    505813.0
# 244 2020-02-07                                    454338.0
# 245 2020-02-08                                    444994.0
# 246 2020-02-09                                    516329.0
# 247 2020-02-10                                    487777.0
# 248 2020-02-11                                    468727.0
# 249 2020-02-12                                    473919.0
# 250 2020-02-13                                    470555.0
# 251 2020-02-14                                    413005.0
# 252 2020-02-15                                    437801.0
# 253 2020-02-16                                    519627.0
# 254 2020-02-17                                    488801.0
# 255 2020-02-18                                    485214.0
#
#      Просмотры телефонов (Легковые с пробегом)  "В кредит" (Объявление) Клики  \
# 0                                      62187.0                        10647.0
# 1                                      65303.0                        11375.0
# 2                                      67271.0                        11554.0
# 3                                      66361.0                        11181.0
# 4                                      65451.0                        10808.0
# 5                                      62524.0                        10588.0
# 6                                      61403.0                        10344.0
# 7                                      62290.0                        10578.0
# 8                                      65120.0                        11453.0
# 9                                      63712.0                        10914.0
# 10                                     62506.0                        11093.0
# 11                                     61638.0                        11032.0
# 12                                     61417.0                        11026.0
# 13                                     59831.0                        10884.0
# 14                                     60959.0                        11329.0
# 15                                     65588.0                        12614.0
# 16                                     66166.0                        12221.0
# 17                                     64656.0                        11807.0
# 18                                     63126.0                        11550.0
# 19                                     63250.0                        11659.0
# 20                                     58771.0                        10848.0
# 21                                     55037.0                        10289.0
# 22                                     61113.0                        12067.0
# 23                                     62178.0                        11462.0
# 24                                     61568.0                        11434.0
# 25                                     61884.0                        11558.0
# 26                                     61367.0                        11534.0
# 27                                     56491.0                        10763.0
# 28                                     59049.0                        11730.0
# 29                                     63009.0                        12888.0
# ..                                         ...                            ...
# 226                                    12856.0                         1812.0
# 227                                    12104.0                         1638.0
# 228                                    11543.0                         1831.0
# 229                                    11644.0                         1625.0
# 230                                    11009.0                         1500.0
# 231                                    11447.0                         1774.0
# 232                                    11937.0                         1733.0
# 233                                    11244.0                         1621.0
# 234                                    11125.0                         1551.0
# 235                                    10975.0                         1502.0
# 236                                    11320.0                         1403.0
# 237                                    10777.0                         1510.0
# 238                                    11521.0                         1586.0
# 239                                    11837.0                         1820.0
# 240                                    12092.0                         1700.0
# 241                                    12374.0                         1736.0
# 242                                    11917.0                         1666.0
# 243                                    12244.0                         1606.0
# 244                                    10492.0                         1642.0
# 245                                    10038.0                         1510.0
# 246                                    11005.0                         1680.0
# 247                                    11143.0                         1667.0
# 248                                    10847.0                         1582.0
# 249                                    11286.0                         1642.0
# 250                                    11424.0                         1689.0
# 251                                    10008.0                         1431.0
# 252                                    10380.0                         1582.0
# 253                                    10779.0                         1755.0
# 254                                    11119.0                         1709.0
# 255                                    11624.0                         1596.0
#
#      "Получить одобрение" (Калькулятор) Подтверждения  \
# 0                                              5436.0
# 1                                              5869.0
# 2                                              6063.0
# 3                                              5778.0
# 4                                              5493.0
# 5                                              5407.0
# 6                                              5262.0
# 7                                              5207.0
# 8                                              5643.0
# 9                                              5578.0
# 10                                             5407.0
# 11                                             5290.0
# 12                                             5225.0
# 13                                             5146.0
# 14                                             5282.0
# 15                                             5878.0
# 16                                             5854.0
# 17                                             5700.0
# 18                                             5562.0
# 19                                             5554.0
# 20                                             5142.0
# 21                                             4906.0
# 22                                             5587.0
# 23                                             5680.0
# 24                                             5549.0
# 25                                             5596.0
# 26                                             5550.0
# 27                                             5045.0
# 28                                             5413.0
# 29                                             5818.0
# ..                                                ...
# 226                                             778.0
# 227                                             841.0
# 228                                             808.0
# 229                                             702.0
# 230                                             674.0
# 231                                             705.0
# 232                                             813.0
# 233                                             772.0
# 234                                             707.0
# 235                                             799.0
# 236                                             729.0
# 237                                             782.0
# 238                                             743.0
# 239                                             841.0
# 240                                             837.0
# 241                                             747.0
# 242                                             747.0
# 243                                             779.0
# 244                                             737.0
# 245                                             647.0
# 246                                             776.0
# 247                                             713.0
# 248                                             737.0
# 249                                             774.0
# 250                                             738.0
# 251                                             635.0
# 252                                             677.0
# 253                                             780.0
# 254                                             811.0
# 255                                             743.0
#
#      "Продолжить" (Большая анкета) Подтверждения  \
# 0                                          638.0
# 1                                          722.0
# 2                                          768.0
# 3                                          718.0
# 4                                          668.0
# 5                                          627.0
# 6                                          645.0
# 7                                          544.0
# 8                                          599.0
# 9                                          695.0
# 10                                         605.0
# 11                                         595.0
# 12                                         628.0
# 13                                         593.0
# 14                                         606.0
# 15                                         650.0
# 16                                         708.0
# 17                                         726.0
# 18                                         656.0
# 19                                         665.0
# 20                                         641.0
# 21                                         554.0
# 22                                         796.0
# 23                                         700.0
# 24                                         704.0
# 25                                         667.0
# 26                                         673.0
# 27                                         618.0
# 28                                         677.0
# 29                                         785.0
# ..                                           ...
# 226                                         60.0
# 227                                         65.0
# 228                                         73.0
# 229                                         64.0
# 230                                         47.0
# 231                                         58.0
# 232                                         66.0
# 233                                         50.0
# 234                                         65.0
# 235                                         63.0
# 236                                         74.0
# 237                                         71.0
# 238                                         67.0
# 239                                         67.0
# 240                                         60.0
# 241                                         57.0
# 242                                         74.0
# 243                                         71.0
# 244                                         50.0
# 245                                         49.0
# 246                                         58.0
# 247                                         53.0
# 248                                         51.0
# 249                                         61.0
# 250                                         57.0
# 251                                         47.0
# 252                                         67.0
# 253                                         66.0
# 254                                         73.0
# 255                                         72.0
#
#      Заявки все (Одобрено, Альтернатива, Отказы)          EorU platform
# 0                                         3559.0  Пользователи  android
# 1                                         3856.0  Пользователи  android
# 2                                         3998.0  Пользователи  android
# 3                                         3824.0  Пользователи  android
# 4                                         3650.0  Пользователи  android
# 5                                         3544.0  Пользователи  android
# 6                                         3534.0  Пользователи  android
# 7                                         3322.0  Пользователи  android
# 8                                         3594.0  Пользователи  android
# 9                                         3713.0  Пользователи  android
# 10                                        3593.0  Пользователи  android
# 11                                        3495.0  Пользователи  android
# 12                                        3538.0  Пользователи  android
# 13                                        3374.0  Пользователи  android
# 14                                        3588.0  Пользователи  android
# 15                                        3890.0  Пользователи  android
# 16                                        3949.0  Пользователи  android
# 17                                        3801.0  Пользователи  android
# 18                                        3780.0  Пользователи  android
# 19                                        3793.0  Пользователи  android
# 20                                        3519.0  Пользователи  android
# 21                                        3295.0  Пользователи  android
# 22                                        3664.0  Пользователи  android
# 23                                        3915.0  Пользователи  android
# 24                                        3769.0  Пользователи  android
# 25                                        3855.0  Пользователи  android
# 26                                        3755.0  Пользователи  android
# 27                                        3379.0  Пользователи  android
# 28                                        3640.0  Пользователи  android
# 29                                        3772.0  Пользователи  android
# ..                                           ...           ...      ...
# 226                                        535.0       События   mobile
# 227                                        529.0       События   mobile
# 228                                        603.0       События   mobile
# 229                                        458.0       События   mobile
# 230                                        426.0       События   mobile
# 231                                        440.0       События   mobile
# 232                                        528.0       События   mobile
# 233                                        480.0       События   mobile
# 234                                        481.0       События   mobile
# 235                                        523.0       События   mobile
# 236                                        534.0       События   mobile
# 237                                        542.0       События   mobile
# 238                                        497.0       События   mobile
# 239                                        554.0       События   mobile
# 240                                        543.0       События   mobile
# 241                                        493.0       События   mobile
# 242                                        536.0       События   mobile
# 243                                        491.0       События   mobile
# 244                                        456.0       События   mobile
# 245                                        410.0       События   mobile
# 246                                        488.0       События   mobile
# 247                                        471.0       События   mobile
# 248                                        510.0       События   mobile
# 249                                        498.0       События   mobile
# 250                                        426.0       События   mobile
# 251                                        407.0       События   mobile
# 252                                        407.0       События   mobile
# 253                                        474.0       События   mobile
# 254                                        516.0       События   mobile
# 255                                        501.0       События   mobile
#
# [256 rows x 9 columns]

# %%
# Credit_Events.to_excel(r'C:\Users\Ospan\Desktop\Kolesa\Credit_Events.xlsx')

# %%
# Credit_Events2 = Credit_Events[['Дата','"В кредит" (Объявление) Клики','"Получить одобрение" (Калькулятор) Подтверждения','"Продолжить" (Большая анкета) Подтверждения','Заявки все (Одобрено, Альтернатива, Отказы)','EorU','platform']]

# %%
Credit_Events.head()
# Out:
#         Дата  Просмотры объявлений (Легковые с пробегом)  \
# 0 2020-01-18                                    367826.0
# 1 2020-01-19                                    384200.0
# 2 2020-01-20                                    393510.0
# 3 2020-01-21                                    390412.0
# 4 2020-01-22                                    387314.0
#
#    Просмотры телефонов (Легковые с пробегом)  "В кредит" (Объявление) Клики  \
# 0                                    62187.0                        10647.0
# 1                                    65303.0                        11375.0
# 2                                    67271.0                        11554.0
# 3                                    66361.0                        11181.0
# 4                                    65451.0                        10808.0
#
#    "Получить одобрение" (Калькулятор) Подтверждения  \
# 0                                            5436.0
# 1                                            5869.0
# 2                                            6063.0
# 3                                            5778.0
# 4                                            5493.0
#
#    "Продолжить" (Большая анкета) Подтверждения  \
# 0                                        638.0
# 1                                        722.0
# 2                                        768.0
# 3                                        718.0
# 4                                        668.0
#
#    Заявки все (Одобрено, Альтернатива, Отказы)          EorU platform
# 0                                       3559.0  Пользователи  android
# 1                                       3856.0  Пользователи  android
# 2                                       3998.0  Пользователи  android
# 3                                       3824.0  Пользователи  android
# 4                                       3650.0  Пользователи  android

# %%
a = Credit_Events.melt(id_vars=["Дата", "platform","EorU"], 
                           value_name="Value",
                           var_name=['"В кредит" (Объявление) Клики'])

a = a.rename(columns={'"В кредит" (Объявление) Клики': 'CreditEvent'})
a[(a['Дата']=='2020-01-18')&(credit['platform']=='mobile')]
# Out:
# C:\Users\Ospan\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#            Дата platform          EorU  \
# 192  2020-01-18   mobile  Пользователи
# 224  2020-01-18   mobile       События
# 448  2020-01-18   mobile  Пользователи
# 480  2020-01-18   mobile       События
# 704  2020-01-18   mobile  Пользователи
# 736  2020-01-18   mobile       События
# 960  2020-01-18   mobile  Пользователи
# 992  2020-01-18   mobile       События
# 1216 2020-01-18   mobile  Пользователи
# 1248 2020-01-18   mobile       События
# 1472 2020-01-18   mobile  Пользователи
# 1504 2020-01-18   mobile       События
#
#                                            CreditEvent     Value
# 192         Просмотры объявлений (Легковые с пробегом)   67402.0
# 224         Просмотры объявлений (Легковые с пробегом)  532624.0
# 448          Просмотры телефонов (Легковые с пробегом)    4840.0
# 480          Просмотры телефонов (Легковые с пробегом)   11659.0
# 704                      "В кредит" (Объявление) Клики    1338.0
# 736                      "В кредит" (Объявление) Клики    1950.0
# 960   "Получить одобрение" (Калькулятор) Подтверждения     638.0
# 992   "Получить одобрение" (Калькулятор) Подтверждения     830.0
# 1216       "Продолжить" (Большая анкета) Подтверждения      64.0
# 1248       "Продолжить" (Большая анкета) Подтверждения      66.0
# 1472       Заявки все (Одобрено, Альтернатива, Отказы)     291.0
# 1504       Заявки все (Одобрено, Альтернатива, Отказы)     495.0

# %%
credit[(credit['Дата']=='2020-01-18')&(credit['platform']=='mobile')]
# Out:
#            Дата platform          EorU  \
# 192  2020-01-18   mobile  Пользователи
# 224  2020-01-18   mobile       События
# 448  2020-01-18   mobile  Пользователи
# 480  2020-01-18   mobile       События
# 704  2020-01-18   mobile  Пользователи
# 736  2020-01-18   mobile       События
# 960  2020-01-18   mobile  Пользователи
# 992  2020-01-18   mobile       События
# 1216 2020-01-18   mobile  Пользователи
# 1248 2020-01-18   mobile       События
# 1472 2020-01-18   mobile  Пользователи
# 1504 2020-01-18   mobile       События
# 1728 2020-01-18   mobile  Пользователи
# 1760 2020-01-18   mobile       События
# 1984 2020-01-18   mobile  Пользователи
# 2016 2020-01-18   mobile       События
# 2240 2020-01-18   mobile  Пользователи
# 2272 2020-01-18   mobile       События
# 2496 2020-01-18   mobile  Пользователи
# 2528 2020-01-18   mobile       События
# 2752 2020-01-18   mobile  Пользователи
# 2784 2020-01-18   mobile       События
# 3008 2020-01-18   mobile  Пользователи
# 3040 2020-01-18   mobile       События
# 3264 2020-01-18   mobile  Пользователи
# 3296 2020-01-18   mobile       События
# 3520 2020-01-18   mobile  Пользователи
# 3552 2020-01-18   mobile       События
# 3776 2020-01-18   mobile  Пользователи
# 3808 2020-01-18   mobile       События
# ...         ...      ...           ...
# 5568 2020-01-18   mobile  Пользователи
# 5600 2020-01-18   mobile       События
# 5824 2020-01-18   mobile  Пользователи
# 5856 2020-01-18   mobile       События
# 6080 2020-01-18   mobile  Пользователи
# 6112 2020-01-18   mobile       События
# 6336 2020-01-18   mobile  Пользователи
# 6368 2020-01-18   mobile       События
# 6592 2020-01-18   mobile  Пользователи
# 6624 2020-01-18   mobile       События
# 6848 2020-01-18   mobile  Пользователи
# 6880 2020-01-18   mobile       События
# 7104 2020-01-18   mobile  Пользователи
# 7136 2020-01-18   mobile       События
# 7360 2020-01-18   mobile  Пользователи
# 7392 2020-01-18   mobile       События
# 7616 2020-01-18   mobile  Пользователи
# 7648 2020-01-18   mobile       События
# 7872 2020-01-18   mobile  Пользователи
# 7904 2020-01-18   mobile       События
# 8128 2020-01-18   mobile  Пользователи
# 8160 2020-01-18   mobile       События
# 8384 2020-01-18   mobile  Пользователи
# 8416 2020-01-18   mobile       События
# 8640 2020-01-18   mobile  Пользователи
# 8672 2020-01-18   mobile       События
# 8896 2020-01-18   mobile  Пользователи
# 8928 2020-01-18   mobile       События
# 9152 2020-01-18   mobile  Пользователи
# 9184 2020-01-18   mobile       События
#
#                                            CreditEvent     Value
# 192         Просмотры объявлений (Легковые с пробегом)   67402.0
# 224         Просмотры объявлений (Легковые с пробегом)  532624.0
# 448          Просмотры телефонов (Легковые с пробегом)    4840.0
# 480          Просмотры телефонов (Легковые с пробегом)   11659.0
# 704                      "В кредит" (Объявление) Клики    1338.0
# 736                      "В кредит" (Объявление) Клики    1950.0
# 960   "Получить одобрение" (Калькулятор) Подтверждения     638.0
# 992   "Получить одобрение" (Калькулятор) Подтверждения     830.0
# 1216       "Продолжить" (Большая анкета) Подтверждения      64.0
# 1248       "Продолжить" (Большая анкета) Подтверждения      66.0
# 1472       Заявки все (Одобрено, Альтернатива, Отказы)     291.0
# 1504       Заявки все (Одобрено, Альтернатива, Отказы)     495.0
# 1728        Просмотры объявлений (Легковые с пробегом)   67402.0
# 1760        Просмотры объявлений (Легковые с пробегом)  532624.0
# 1984         Просмотры телефонов (Легковые с пробегом)    4840.0
# 2016         Просмотры телефонов (Легковые с пробегом)   11659.0
# 2240                     "В кредит" (Объявление) Клики    1338.0
# 2272                     "В кредит" (Объявление) Клики    1950.0
# 2496  "Получить одобрение" (Калькулятор) Подтверждения     638.0
# 2528  "Получить одобрение" (Калькулятор) Подтверждения     830.0
# 2752       "Продолжить" (Большая анкета) Подтверждения      64.0
# 2784       "Продолжить" (Большая анкета) Подтверждения      66.0
# 3008       Заявки все (Одобрено, Альтернатива, Отказы)     291.0
# 3040       Заявки все (Одобрено, Альтернатива, Отказы)     495.0
# 3264        Просмотры объявлений (Легковые с пробегом)   67402.0
# 3296        Просмотры объявлений (Легковые с пробегом)  532624.0
# 3520         Просмотры телефонов (Легковые с пробегом)    4840.0
# 3552         Просмотры телефонов (Легковые с пробегом)   11659.0
# 3776                     "В кредит" (Объявление) Клики    1338.0
# 3808                     "В кредит" (Объявление) Клики    1950.0
# ...                                                ...       ...
# 5568  "Получить одобрение" (Калькулятор) Подтверждения     638.0
# 5600  "Получить одобрение" (Калькулятор) Подтверждения     830.0
# 5824       "Продолжить" (Большая анкета) Подтверждения      64.0
# 5856       "Продолжить" (Большая анкета) Подтверждения      66.0
# 6080       Заявки все (Одобрено, Альтернатива, Отказы)     291.0
# 6112       Заявки все (Одобрено, Альтернатива, Отказы)     495.0
# 6336        Просмотры объявлений (Легковые с пробегом)   67402.0
# 6368        Просмотры объявлений (Легковые с пробегом)  532624.0
# 6592         Просмотры телефонов (Легковые с пробегом)    4840.0
# 6624         Просмотры телефонов (Легковые с пробегом)   11659.0
# 6848                     "В кредит" (Объявление) Клики    1338.0
# 6880                     "В кредит" (Объявление) Клики    1950.0
# 7104  "Получить одобрение" (Калькулятор) Подтверждения     638.0
# 7136  "Получить одобрение" (Калькулятор) Подтверждения     830.0
# 7360       "Продолжить" (Большая анкета) Подтверждения      64.0
# 7392       "Продолжить" (Большая анкета) Подтверждения      66.0
# 7616       Заявки все (Одобрено, Альтернатива, Отказы)     291.0
# 7648       Заявки все (Одобрено, Альтернатива, Отказы)     495.0
# 7872        Просмотры объявлений (Легковые с пробегом)   67402.0
# 7904        Просмотры объявлений (Легковые с пробегом)  532624.0
# 8128         Просмотры телефонов (Легковые с пробегом)    4840.0
# 8160         Просмотры телефонов (Легковые с пробегом)   11659.0
# 8384                     "В кредит" (Объявление) Клики    1338.0
# 8416                     "В кредит" (Объявление) Клики    1950.0
# 8640  "Получить одобрение" (Калькулятор) Подтверждения     638.0
# 8672  "Получить одобрение" (Калькулятор) Подтверждения     830.0
# 8896       "Продолжить" (Большая анкета) Подтверждения      64.0
# 8928       "Продолжить" (Большая анкета) Подтверждения      66.0
# 9152       Заявки все (Одобрено, Альтернатива, Отказы)     291.0
# 9184       Заявки все (Одобрено, Альтернатива, Отказы)     495.0
#
# [72 rows x 5 columns]

# %%
a.to_excel(r'C:\Users\Ospan\Desktop\Kolesa\Credit_divided.xlsx')

# %% [markdown]
# # Second table

# %%
df_Sent_First_Message=df_Sent_First_Message.drop(['eventName'],axis=1)

# %%
df_Sent_First_Message=df_Sent_First_Message.rename(columns={"hitIdCount": "hitID", "anonymousIdCount": "userID"})

# %%
df_Sent_First_Message.head()
# Out:
#         date  hitID  userID platform
# 0 2020-01-18   3267     395  desktop
# 1 2020-01-19   1742     404  desktop
# 2 2020-01-20   3190     559  desktop
# 3 2020-01-21   2653     550  desktop
# 4 2020-01-22   2455     585  desktop

# %%
df_Sent_First_Message_App=df_Sent_First_Message_App.drop(['event_name'], axis=1)

# %%
df_Sent_First_Message_App = df_Sent_First_Message_App.rename(columns={"countHits": "hitID", "user_id": "userID"})

# %%
df_Sent_First_Message_App.head()
# Out:
#         date  hitID  userID platform
# 0 2020-01-18  46528   11861  android
# 1 2020-01-18  16903    3769      ios
# 2 2020-01-19  18550    3994      ios
# 3 2020-01-19  51808   12867  android
# 4 2020-01-20  59969   12904  android

# %%
df_Sent_First_Message = df_Sent_First_Message.append([df_Sent_First_Message_App],ignore_index = True)

# %%
df_Sent_First_Message.head()
# Out:
#         date  hitID  userID platform
# 0 2020-01-18   3267     395  desktop
# 1 2020-01-19   1742     404  desktop
# 2 2020-01-20   3190     559  desktop
# 3 2020-01-21   2653     550  desktop
# 4 2020-01-22   2455     585  desktop

# %% [markdown]
# # Prepare data for join

# %%
df_Sent_First_Message = df_Sent_First_Message.melt(id_vars=["date", "platform","userID"], 
                           value_name="Value",
                           var_name=["hitID"])

df_Sent_First_Message = df_Sent_First_Message.melt(id_vars=["date", "platform","Value","hitID"], 
                           value_name="ValueU",
                           var_name=["userID"])

# %%
df_Sent_First_Message.head()
# Out:
#         date platform  Value  hitID  userID  ValueU
# 0 2020-01-18  desktop   3267  hitID  userID     395
# 1 2020-01-19  desktop   1742  hitID  userID     404
# 2 2020-01-20  desktop   3190  hitID  userID     559
# 3 2020-01-21  desktop   2653  hitID  userID     550
# 4 2020-01-22  desktop   2455  hitID  userID     585

# %%
df_user = df_Sent_First_Message[['date','platform','ValueU','userID']]

# %%
df_user = df_user.rename(columns={"ValueU": "Value", "userID": "EorU"})

# %%
df_user = df_user.replace({'EorU': {'userID': 'Пользователи'}})

# %%
df_user.head()
# Out:
#         date platform  Value          EorU
# 0 2020-01-18  desktop    395  Пользователи
# 1 2020-01-19  desktop    404  Пользователи
# 2 2020-01-20  desktop    559  Пользователи
# 3 2020-01-21  desktop    550  Пользователи
# 4 2020-01-22  desktop    585  Пользователи

# %%
df_hit = df_Sent_First_Message[['date','platform','Value','hitID']]

# %%
df_hit = df_hit.rename(columns={"hitID": "EorU"})

# %%
df_hit = df_hit.replace({'EorU': {'hitID': 'События'}})

# %%
df_hit.head()
# Out:
#         date platform  Value     EorU
# 0 2020-01-18  desktop   3267  События
# 1 2020-01-19  desktop   1742  События
# 2 2020-01-20  desktop   3190  События
# 3 2020-01-21  desktop   2653  События
# 4 2020-01-22  desktop   2455  События

# %%
df_message = df_user.append([df_hit],ignore_index = True)

# %%
df_message = df_message.rename(columns={"date": "Дата"})

# %%
df_message = df_message.rename(columns={"Value": "Message"})

# %%
df_message.head()
# Out:
#         Дата platform  Message          EorU
# 0 2020-01-18  desktop      395  Пользователи
# 1 2020-01-19  desktop      404  Пользователи
# 2 2020-01-20  desktop      559  Пользователи
# 3 2020-01-21  desktop      550  Пользователи
# 4 2020-01-22  desktop      585  Пользователи

# %%
# df_Sent_First_Message.to_excel(r'C:\Users\Ospan\Desktop\Kolesa\Sent_First_Message.xlsx')

# %% [markdown]
# # Third table

# %%
# df_baza_listers = pd.merge(df_baza, df_listers, on=['date','platform'])
# df_baza_listers = df_baza_listers.groupby('date')['objem_bazy','listers'].sum()

# %%
# df_baza_listers = df_baza_listers.reset_index()

df_baza_listers = df_baza_listers.groupby('date')['objem_bazy','listers'].sum()

# %%
df_baza_listers = df_baza_listers.reset_index()

# %%
df_baza_listers.head()
# df_baza_listers.to_excel(r'C:\Users\Ospan\Desktop\Kolesa\Baza_Listers_New.xlsx')
df_baza_listers.dtypes
# Out:
# date          datetime64[ns]
# platform              object
# objem_bazy             int64
# listers                int64
# dtype: object

# %%
# df_baza_listers.to_excel(r'C:\Users\Ospan\Desktop\Kolesa\Baza_Listers.xlsx')

# %%
a = df_baza_listers.melt(id_vars=["date"], 
                           value_name="Value",
                           var_name=['objem_bazy'])

a = a.rename(columns={'objem_bazy': 'Параметр', 'date':'Дата'})

# %%
a.head()
# Out:
#         Дата    Параметр   Value
# 0 2020-01-18  objem_bazy  147191
# 1 2020-01-19  objem_bazy  148821
# 2 2020-01-20  objem_bazy  150136
# 3 2020-01-21  objem_bazy  149944
# 4 2020-01-22  objem_bazy  148982

# %%
a.to_excel(r'C:\Users\Ospan\Desktop\Kolesa\Baza_Listers_New_Transformed.xlsx')

# %% [markdown]
# # Fourth table ----- message+credit

# %%
df_message_credit = pd.merge()

# %%
Credit_Events.dtypes
# Out:
# Дата                                                datetime64[ns]
# Просмотры объявлений (Легковые с пробегом)                 float64
# Просмотры телефонов (Легковые с пробегом)                  float64
# "В кредит" (Объявление) Клики                              float64
# "Получить одобрение" (Калькулятор) Подтверждения           float64
# "Продолжить" (Большая анкета) Подтверждения                float64
# Заявки все (Одобрено, Альтернатива, Отказы)                float64
# EorU                                                        object
# platform                                                    object
# dtype: object

# %%
df_message.dtypes
# Out:
# Дата        datetime64[ns]
# platform            object
# Message              int64
# EorU                object
# dtype: object

# %%
result = pd.merge(Credit_Events,
                 df_message,
                 on=['Дата','platform','EorU'], 
                 how='left')

# %%
# result = pd.DataFrame()

# %%
result.to_excel(r'C:\Users\Ospan\Desktop\Kolesa\Credit_Message.xlsx')

# %%
gggg.to
